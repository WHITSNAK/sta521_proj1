# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
df = pd.read_csv('data/sonoma_data_clean.csv', parse_dates=['epoch_datetime'])

# %%
# # only nodeid in network dataset
# df = df[df.nodeid.isin(df[df.source=='net'].nodeid.unique())]
# df = df.groupby(['epoch_datetime', 'nodeid']).last()
# df.to_csv('data/sonoma_data_clean.csv', index=False)

# %%
df = df.reset_index()

# %%
subset = df[df.epoch_datetime.dt.to_period('D')=='2004-05-02']

fig, ax = plt.subplots(figsize=(15, 6))
sns.lineplot(data=subset, y='humidity', x='epoch_datetime', ax=ax)
# Out:
# <AxesSubplot:xlabel='epoch_datetime', ylabel='humidity'>

# %%
subset = df[(df.epoch_datetime.dt.to_period('D')>='2004-05-01')&(df.epoch_datetime.dt.to_period('D')<='2004-05-30')]

fig, ax = plt.subplots(figsize=(15, 6))
sns.lineplot(data=subset, y='humid_temp', x='epoch_datetime', ax=ax)
